# %% [markdown]
# <a href="https://colab.research.google.com/github/aizatulin69/goit-ds-hw-08/blob/main/Hw8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import pandas as pd
import os
print(os.path.exists("data.zip"))
print(zipfile.is_zipfile("data.zip"))

def df_from_zip_folder(folder_name):
    dfs = []
    with zipfile.ZipFile("/content/data.zip") as z:
        for name in z.namelist():
            if name.startswith(folder_name) and name.endswith(".csv"):
                with z.open(name) as f:
                    dfs.append(pd.read_csv(f))
    return pd.concat(dfs, ignore_index=True)

df_idle = df_from_zip_folder("idle/")
# Out:
# True
# False
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# /tmp/ipython-input-3313482314.py in <cell line: 0>()
#      14     return pd.concat(dfs, ignore_index=True)
#      15
# ---> 16 df_idle = df_from_zip_folder("idle/")
#
# /tmp/ipython-input-3313482314.py in df_from_zip_folder(folder_name)
#       7 def df_from_zip_folder(folder_name):
#       8     dfs = []
# ----> 9     with zipfile.ZipFile("/content/data.zip") as z:
#      10         for name in z.namelist():
#      11             if name.startswith(folder_name) and name.endswith(".csv"):
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1368         try:
#    1369             if mode == 'r':
# -> 1370                 self._RealGetContents()
#    1371             elif mode in ('w', 'x'):
#    1372                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.12/zipfile/__init__.py in _RealGetContents(self)
#    1435             raise BadZipFile("File is not a zip file")
#    1436         if not endrec:
# -> 1437             raise BadZipFile("File is not a zip file")
#    1438         if self.debug > 1:
#    1439             print(endrec)
#
# BadZipFile: File is not a zip file
